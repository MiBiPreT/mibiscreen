# %% [markdown]
# # MiBiPreT example: NA screening using Griftpark data
#
# ## Background: Griftpark contaminant site
#
# Text to be added.
#
# ## Data Analysis
#
# Text to be added.

# %%
#!pip install mibipret

# %% [markdown]
# Comment optional when package is not pip-installed:

# %%
import sys
path = '/home/alraune/GitHub/MiBiPreT/mibipret'
sys.path.append(path) # append the path to module

# %%
#from mibipret.data.data import load_csv, standardize

# %%
import mibipret.data.data as md
import mibipret.analysis.sample.screening_NA as na

# %% [markdown]
# ### Data handling
#
# **Load in data:**
#
# Returns loaded data as DataFrame. Will be reported when verbose flag is `True`.

# %%
file_path = './grift_BTEXIIN.csv'
data_raw,units = md.load_csv(file_path,verbose=False)

# %% [markdown]
# **Standardization of input data:**
#
# Runs all checks on data, i.e. column names, units and values in one go and returns transformed data with standard column names and valueas in numerical type where possible. Data is reduced to those columns containing known quantities.

# %%
data,units = md.standardize(data_raw, reduce = True, verbose=True)
# Out:
# ================================================================
#  Running function 'standardize()' on data
# ================================================================
# 23 quantities identified and renamed:
# -------------------------------------
# sample nr  -->  sample_nr
# obs_well  -->  obs_well
# well type  -->  well_type
# Depth  -->  depth
# pH  -->  pH
# EC  -->  EC
# Redox  -->  redoxpot
# pE  -->  pE
# NPOC  -->  NOPC
# sulfate  -->  sulfate
# ammonium  -->  ammonium
# sulfide  -->  sulfide
# methane  -->  methane
# Fe II  -->  ironII
# Mn  -->  manganese
# Benzene  -->  benzene
# Toluene  -->  toluene
# Ethylbenzene  -->  ethylbenzene
# P/M Xylene  -->  pm_xylene
# O Xylene  -->  o_xylene
# Indane  -->  indane
# Indene  -->  indene
# Naphthalene  -->  naphthalene
# ________________________________________________________________
# 6 quantities not identified (and removed) from standard data:
# --------------------------------------------------------------
# Cumene
# Propylbenzene
# M-Ethyltoluene
# O-Ethyltoluene
# 1,2,4-Trimethylbenzene
# 1,2,3-Trimethylbenzene
# ================================================================
#  Running function 'check_units()' on data
# ================================================================
# ________________________________________________________________
#  All identified quantities given in requested units.
# ================================================================
# ================================================================
#  Running function 'check_values()' on data
# ================================================================
# WARNING: Cound not transform 'depth' to numerical values
# ________________________________________________________________
# Quantities with values transformed to numerical s(int/float):
# -----------------------------------------------------------
# redoxpot
# pH
# EC
# pE
# NOPC
# sulfate
# sulfide
# ammonium
# methane
# ironII
# manganese
# benzene
# toluene
# ethylbenzene
# pm_xylene
# o_xylene
# indane
# indene
# naphthalene
# ================================================================
# ================================================================

# %% [markdown]
# ### Natural Attenuation (NA) Screening
#
# Performing NA screening step by step.

# %% [markdown]
# **Calculation of number of electrons for reduction**
#
# Returns pandas-Series with total amount of electron reductors per well in [mmol e-/l]:

# %%
tot_reduct = na.reductors(data,verbose = True,ea_group = 'ONSFe')
# Out:
# ==============================================================
#  Running function 'reductors()' on data
# ==============================================================
# WARNING: No data on oxygen given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on nitrate given, zero concentration assumed.
# ________________________________________________________________
# Total amount of electron reductors per well in [mmol e-/l] is:
# 1     17.012271
# 2     13.866108
# 3      1.942974
# 4      0.009434
# 5      0.092681
# 6      0.749220
# 7      0.416233
# 8      6.576483
# 9     10.600622
# 10    19.823788
# 11     3.303222
# 12    14.755178
# 13     3.552962
# 14     7.344570
# 15    11.340408
# 16    14.210188
# 17    11.822679
# 18    17.483449
# 19     0.915713
# 20     0.009434
# 21     1.165453
# 22     0.851334
# 23     2.406377
# 24    21.861353
# 25     2.156417
# 26     0.056677
# Name: total_reductors, dtype: float64
# ----------------------------------------------------------------

# %% [markdown]
# **Calculation of number of electrons needed for oxidation**
#
# Returns pandas-Series with total amount of oxidators per well in [mmol e-/l]:

# %%
tot_oxi = na.oxidators(data,verbose = True, contaminant_group='BTEXIIN')
# Out:
# ==============================================================
#  Running function 'oxidators()' on data
# ==============================================================
# Total amount of oxidators per well in [mmol e-/l] is:
# 1     0.025072
# 2     0.044267
# 3     1.566197
# 4     3.700148
# 5     3.005697
# 6     2.095891
# 7     1.096625
# 8     0.609639
# 9     0.071786
# 10    0.009096
# 11    0.007641
# 12    3.387844
# 13    0.193833
# 14    3.508261
# 15    0.226966
# 16    0.008771
# 17    0.011772
# 18    0.044267
# 19    3.270139
# 20    4.455273
# 21    3.749325
# 22    3.161460
# 23    5.014808
# 24    0.080802
# 25    0.006877
# 26    0.010242
# Name: total_oxidators, dtype: float64
# -----------------------------------------------------

# %% [markdown]
# **Calculation of number of electron balance**
#
# Returns pandas-Series with ratio of reductors to oxidators. If value below 1, available electrons for reduction are not sufficient for reaction and thus NA is potentially not taking place.

# %%
e_bal = na.electron_balance(data,verbose = True)
# Out:
# ==============================================================
#  Running function 'electron_balance()' on data
# ==============================================================
# WARNING: No data on oxygen given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on nitrate given, zero concentration assumed.
# ________________________________________________________________
# Electron balance e_red/e_cont is:
# 1      678.527393
# 2      313.237373
# 3        1.240568
# 4        0.002550
# 5        0.030835
# 6        0.357471
# 7        0.379558
# 8       10.787503
# 9      147.670324
# 10    2179.511325
# 11     432.278699
# 12       4.355330
# 13      18.330004
# 14       2.093507
# 15      49.965302
# 16    1620.183485
# 17    1004.339738
# 18     394.953611
# 19       0.280023
# 20       0.002117
# 21       0.310843
# 22       0.269285
# 23       0.479854
# 24     270.553835
# 25     313.558012
# 26       5.533519
# Name: e_balance, dtype: float64
# ---------------------------------

# %% [markdown]
# **Calculation of "traffic light" based on electron balance**
#
# Returns pandas-Series with traffic light (red/yellow/green) if NA is taking place based on electron balance. Red corresponds to a electron balance below 1 where available electrons for reduction are not sufficient and thus NA is potentially not taking place.

# %%
na_traffic = na.NA_traffic(data,verbose = True)
# Out:
# ==============================================================
#  Running function 'NA_traffic()' on data
# ==============================================================
# WARNING: No data on oxygen given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on nitrate given, zero concentration assumed.
# ________________________________________________________________
# Evaluation if natural attenuation (NA) is ongoing:
# --------------------------------------------------
# Red light: Reduction is limited at 9 out of 26 locations
# Green light: Reduction is limited at 17 out of 26 locations
# Yellow light: No decision possible at 0 out of 26 locations
# ________________________________________________________________

# %% [markdown]
# ### Evaluation of intervention threshold exceedance
#
# **Calculation of total concentration of contaminants/specified group of contaminants**
#
# Returns pandas-Series with total concentrations of contaminants per well in [ug/l]:

# %%
tot_cont = na.total_contaminant_concentration(data,verbose = True,contaminant_group='BTEXIIN')
# Out:
# ==============================================================
#  Running function 'total_contaminant_concentration()' on data
# ==============================================================
# Total concentration of BTEXIIN in [ug/l] is:
# 1        66.0
# 2       116.0
# 3      4101.0
# 4      9657.0
# 5      7839.0
# 6      5449.0
# 7      2822.0
# 8      1595.0
# 9       184.0
# 10       24.0
# 11       20.0
# 12     8983.0
# 13      498.0
# 14     9224.0
# 15      593.0
# 16       23.0
# 17       31.0
# 18      116.0
# 19     8542.0
# 20    11695.0
# 21     9804.0
# 22     8306.0
# 23    13132.0
# 24      211.1
# 25       18.1
# 26       26.9
# Name: total_contaminants, dtype: float64
# --------------------------------------------------

# %% [markdown]
# **Calculation of "traffic light" for threshold exceedance**
#
# Returns pandas-DataFrame (similar to input data, including well specification) with intervention threshold exceedance analysis:
# * traffic light if well requires intervention (red/yellow/green)
# * number of contaminants exceeding the intervention value
# * list of contaminants above the threshold of intervention

# %%
na_intervention = na.thresholds_for_intervention(data,verbose = True,contaminant_group='BTEXIIN')
#na.thresholds_for_intervention?
display(na_intervention)
# Out:
# ==============================================================
#  Running function 'thresholds_for_intervention()' on data
# ==============================================================
# Evaluation of contaminant concentrations exceeding intervention values for BTEXIIN:
# ------------------------------------------------------------------------------------
# Red light: Intervention values exceeded for 16 out of 26 locations
# green light: Concentrations below intervention values at 10 out of 26 locations
# Yellow light: No decision possible at 0 out of 26 locations
# ________________________________________________________________
#        sample_nr           obs_well intervention_traffic  intervention_number  \
# 1   2019-031-001        A-32mm-52,5                green                    0
# 2   2019-031-002        A-32mm-65,5                green                    0
# 3   2019-031-009        B-MLS1-3-12                  red                    4
# 4   2019-031-011      B-MLS1-5-15,5                  red                    6
# 5   2019-031-012        B-MLS1-6-17                  red                    6
# 6   2019-031-013        B-MLS1-7-19                  red                    5
# 7   2019-031-014      B-MLS2-1-20,5                  red                    7
# 8   2019-031-018        B-MLS2-5-28                  red                    6
# 9   2019-031-020        B-MLS2-7-31                green                    0
# 10  2019-031-004        B-32mm44-45                green                    0
# 11  2019-031-006       B-32mm-63-64                green                    0
# 12  2019-031-029        B2-MLS1-1-7                  red                    7
# 13  2019-031-031     B2-MLS1-3-10,5                  red                    3
# 14  2019-031-033       B2-MLS1-5-14                  red                    7
# 15  2019-031-034     B2-MLS1-6-15,5                  red                    2
# 16  2019-031-036       B2-MLS2-1-20                green                    0
# 17  2019-031-039       B2-MLS2-4-43                green                    0
# 18  2019-031-028  B2-32mm-64,5-65,5                green                    0
# 19  2019-031-048      C-MLS1-1-15,5                  red                    6
# 20  2019-031-050        C-MLS1-3-19                  red                    6
# 21  2019-031-054        C-MLS1-7-26                  red                    7
# 22  2019-031-044     C-32mm-38,5-39                  red                    7
# 23  2019-031-047     C-32mm-45,5-46                  red                    7
# 24  2019-031-059                Pb1                  red                    1
# 25  2019-031-062                 60                green                    0
# 26  2019-031-063              BW205                green                    0
#
#                             intervention_contaminants
# 1                                                  []
# 2                                                  []
# 3        [benzene, ethylbenzene, indane, naphthalene]
# 4   [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 5   [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 6   [benzene, ethylbenzene, pm_xylene, indane, nap...
# 7   [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 8   [benzene, ethylbenzene, o_xylene, indane, inde...
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 13                       [benzene, pm_xylene, indane]
# 14  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 15                             [benzene, naphthalene]
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 20  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 21  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 22  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 23  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 24                                          [benzene]
# 25                                                 []
# 26                                                 []

# %% [markdown]
# ### Natural Attenuation (NA) Screening in one go
#
# Performing complete NA screening and evaluation of intervention threshold exceedance.
#
# Returns pandas-DataFrame (including well specification from input data) with NA screening results and intervention threshold exceedance analysis:
# * total amount of electron reductors per well in [mmol e-/l]
# * total amount of oxidators per well in [mmol e-/l]
# * electron balance, ratio of reductors to oxidators
# * NA - traffic light (red/yellow/green) if NA is taking place based on electron balance
# * total concentrations of contaminants per well in [ug/l]
# * Intervention traffic light per well (red/yellow/green)
# * number of contaminants exceeding the intervention value
# * list of contaminants above the threshold of intervention

# %%
data_na = na.screening_NA(data,verbose = True)
# Out:
# ==============================================================
#  Running function 'screening_NA()' on data
# ==============================================================
# ==============================================================
#  Running function 'total_contaminant_concentration()' on data
# ==============================================================
# Total concentration of BTEXIIN in [ug/l] is:
# 1        66.0
# 2       116.0
# 3      4101.0
# 4      9657.0
# 5      7839.0
# 6      5449.0
# 7      2822.0
# 8      1595.0
# 9       184.0
# 10       24.0
# 11       20.0
# 12     8983.0
# 13      498.0
# 14     9224.0
# 15      593.0
# 16       23.0
# 17       31.0
# 18      116.0
# 19     8542.0
# 20    11695.0
# 21     9804.0
# 22     8306.0
# 23    13132.0
# 24      211.1
# 25       18.1
# 26       26.9
# Name: total_contaminants, dtype: float64
# --------------------------------------------------
# ==============================================================
#  Running function 'thresholds_for_intervention()' on data
# ==============================================================
# Evaluation of contaminant concentrations exceeding intervention values for BTEXIIN:
# ------------------------------------------------------------------------------------
# Red light: Intervention values exceeded for 16 out of 26 locations
# green light: Concentrations below intervention values at 10 out of 26 locations
# Yellow light: No decision possible at 0 out of 26 locations
# ________________________________________________________________
# ==============================================================
#  Running function 'reductors()' on data
# ==============================================================
# WARNING: No data on oxygen given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on nitrate given, zero concentration assumed.
# ________________________________________________________________
# Total amount of electron reductors per well in [mmol e-/l] is:
# 1     17.012271
# 2     13.866108
# 3      1.942974
# 4      0.009434
# 5      0.092681
# 6      0.749220
# 7      0.416233
# 8      6.576483
# 9     10.600622
# 10    19.823788
# 11     3.303222
# 12    14.755178
# 13     3.552962
# 14     7.344570
# 15    11.340408
# 16    14.210188
# 17    11.822679
# 18    17.483449
# 19     0.915713
# 20     0.009434
# 21     1.165453
# 22     0.851334
# 23     2.406377
# 24    21.861353
# 25     2.156417
# 26     0.056677
# Name: total_reductors, dtype: float64
# ----------------------------------------------------------------
# ==============================================================
#  Running function 'oxidators()' on data
# ==============================================================
# Total amount of oxidators per well in [mmol e-/l] is:
# 1     0.025072
# 2     0.044267
# 3     1.566197
# 4     3.700148
# 5     3.005697
# 6     2.095891
# 7     1.096625
# 8     0.609639
# 9     0.071786
# 10    0.009096
# 11    0.007641
# 12    3.387844
# 13    0.193833
# 14    3.508261
# 15    0.226966
# 16    0.008771
# 17    0.011772
# 18    0.044267
# 19    3.270139
# 20    4.455273
# 21    3.749325
# 22    3.161460
# 23    5.014808
# 24    0.080802
# 25    0.006877
# 26    0.010242
# Name: total_oxidators, dtype: float64
# -----------------------------------------------------
# ==============================================================
#  Running function 'electron_balance()' on data
# ==============================================================
# WARNING: No data on oxygen given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on nitrate given, zero concentration assumed.
# ________________________________________________________________
# Electron balance e_red/e_cont is:
# 1      678.527393
# 2      313.237373
# 3        1.240568
# 4        0.002550
# 5        0.030835
# 6        0.357471
# 7        0.379558
# 8       10.787503
# 9      147.670324
# 10    2179.511325
# 11     432.278699
# 12       4.355330
# 13      18.330004
# 14       2.093507
# 15      49.965302
# 16    1620.183485
# 17    1004.339738
# 18     394.953611
# 19       0.280023
# 20       0.002117
# 21       0.310843
# 22       0.269285
# 23       0.479854
# 24     270.553835
# 25     313.558012
# 26       5.533519
# Name: e_balance, dtype: float64
# ---------------------------------
# ==============================================================
#  Running function 'NA_traffic()' on data
# ==============================================================
# WARNING: No data on oxygen given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on nitrate given, zero concentration assumed.
# ________________________________________________________________
# Evaluation if natural attenuation (NA) is ongoing:
# --------------------------------------------------
# Red light: Reduction is limited at 9 out of 26 locations
# Green light: Reduction is limited at 17 out of 26 locations
# Yellow light: No decision possible at 0 out of 26 locations
# ________________________________________________________________

# %%
display(data_na)
# Out:
#        sample_nr           obs_well  total_reductors  total_oxidators  \
# 1   2019-031-001        A-32mm-52,5        17.012271         0.025072
# 2   2019-031-002        A-32mm-65,5        13.866108         0.044267
# 3   2019-031-009        B-MLS1-3-12         1.942974         1.566197
# 4   2019-031-011      B-MLS1-5-15,5         0.009434         3.700148
# 5   2019-031-012        B-MLS1-6-17         0.092681         3.005697
# 6   2019-031-013        B-MLS1-7-19         0.749220         2.095891
# 7   2019-031-014      B-MLS2-1-20,5         0.416233         1.096625
# 8   2019-031-018        B-MLS2-5-28         6.576483         0.609639
# 9   2019-031-020        B-MLS2-7-31        10.600622         0.071786
# 10  2019-031-004        B-32mm44-45        19.823788         0.009096
# 11  2019-031-006       B-32mm-63-64         3.303222         0.007641
# 12  2019-031-029        B2-MLS1-1-7        14.755178         3.387844
# 13  2019-031-031     B2-MLS1-3-10,5         3.552962         0.193833
# 14  2019-031-033       B2-MLS1-5-14         7.344570         3.508261
# 15  2019-031-034     B2-MLS1-6-15,5        11.340408         0.226966
# 16  2019-031-036       B2-MLS2-1-20        14.210188         0.008771
# 17  2019-031-039       B2-MLS2-4-43        11.822679         0.011772
# 18  2019-031-028  B2-32mm-64,5-65,5        17.483449         0.044267
# 19  2019-031-048      C-MLS1-1-15,5         0.915713         3.270139
# 20  2019-031-050        C-MLS1-3-19         0.009434         4.455273
# 21  2019-031-054        C-MLS1-7-26         1.165453         3.749325
# 22  2019-031-044     C-32mm-38,5-39         0.851334         3.161460
# 23  2019-031-047     C-32mm-45,5-46         2.406377         5.014808
# 24  2019-031-059                Pb1        21.861353         0.080802
# 25  2019-031-062                 60         2.156417         0.006877
# 26  2019-031-063              BW205         0.056677         0.010242
#
#       e_balance na_traffic_light  total_contaminants intervention_traffic  \
# 1    678.527393            green                66.0                green
# 2    313.237373            green               116.0                green
# 3      1.240568            green              4101.0                  red
# 4      0.002550              red              9657.0                  red
# 5      0.030835              red              7839.0                  red
# 6      0.357471              red              5449.0                  red
# 7      0.379558              red              2822.0                  red
# 8     10.787503            green              1595.0                  red
# 9    147.670324            green               184.0                green
# 10  2179.511325            green                24.0                green
# 11   432.278699            green                20.0                green
# 12     4.355330            green              8983.0                  red
# 13    18.330004            green               498.0                  red
# 14     2.093507            green              9224.0                  red
# 15    49.965302            green               593.0                  red
# 16  1620.183485            green                23.0                green
# 17  1004.339738            green                31.0                green
# 18   394.953611            green               116.0                green
# 19     0.280023              red              8542.0                  red
# 20     0.002117              red             11695.0                  red
# 21     0.310843              red              9804.0                  red
# 22     0.269285              red              8306.0                  red
# 23     0.479854              red             13132.0                  red
# 24   270.553835            green               211.1                  red
# 25   313.558012            green                18.1                green
# 26     5.533519            green                26.9                green
#
#     intervention_number                          intervention_contaminants
# 1                     0                                                 []
# 2                     0                                                 []
# 3                     4       [benzene, ethylbenzene, indane, naphthalene]
# 4                     6  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 5                     6  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 6                     5  [benzene, ethylbenzene, pm_xylene, indane, nap...
# 7                     7  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 8                     6  [benzene, ethylbenzene, o_xylene, indane, inde...
# 9                     0                                                 []
# 10                    0                                                 []
# 11                    0                                                 []
# 12                    7  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 13                    3                       [benzene, pm_xylene, indane]
# 14                    7  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 15                    2                             [benzene, naphthalene]
# 16                    0                                                 []
# 17                    0                                                 []
# 18                    0                                                 []
# 19                    6  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 20                    6  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 21                    7  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 22                    7  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 23                    7  [benzene, ethylbenzene, pm_xylene, o_xylene, i...
# 24                    1                                          [benzene]
# 25                    0                                                 []
# 26                    0                                                 []
